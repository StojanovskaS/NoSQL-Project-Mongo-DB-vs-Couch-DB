# %%
import json
import os
import pymongo

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://admin:admin@cluster0.72sux.mongodb.net/mongonosqlproject?retryWrites=true&w=majority')

# %%
db = client["mongonosqlproject"]

# %%
collection = db["projectdata"]

# %%
import glob
for name in  glob.glob('C:/Users/Sandra/Downloads/documentsForNoSql/*.json'):
    print(name)
# Out:
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql0.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql1.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql100.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql1000.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10000.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10001.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10002.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10003.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10004.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10005.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10006.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10007.json
# C:/Users/Sandra/Downloads/documentsForNoSql\jsonFileNoSql10008.json
# ...

# %%
import glob
result = list()
for filename in glob.glob('C:/Users/Sandra/Downloads/documentsForNoSql/*.json'):
    with open(os.path.join(os.getcwd(), filename), 'r') as f: # open in readonly mode
        dataDocument = json.loads(f.read())
        result.append(dataDocument)

# %%
result[0]
# Out:
# {'adult': 'False',
#  'budget': 30000000.0,
#  'genres': [{'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 10751, 'name': 'Family'}],
#  'id': '862',
#  'imdb_id': 'tt0114709',
#  'original_language': 'en',
#  'original_title': 'Toy Story',
#  'overview': "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.",
#  'popularity': 21.946943,
#  'poster_path': '/rhIRbceoE9lR4veEXuwCC2wARtG.jpg',
#  'production_companies': [{'name': 'Pixar Animation Studios', 'id': 3}],
#  'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]",
#  'release_date': '1995-10-30',
#  'revenue': 373554033.0,
#  'runtime': 81.0,
#  'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]",
# ...

# %%
collection.insert_many(result)
